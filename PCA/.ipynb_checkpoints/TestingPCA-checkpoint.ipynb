# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns; sns.set()
from sklearn.decomposition import PCA
from sklearn.decomposition import PCA

from package import encoder
# Out:
# Loaded  1 encoders.

# %%
csv = pd.read_csv("Halpha.csv", encoding='latin-1', index_col="ID")
#csv = encoder.encode_DataFrame(train)
df = pd.DataFrame()

# %%
csv.columns
# Out:
# Index(['Field', 'RA', 'DEC', 'FWHM', 'ISOarea', 'KRON_RADIUS', 'MU_MAX',
#        'nDet_PStotal', 'PhotoFlagDet', 'CLASS_STAR', 'u_PStotal',
#        'J0378_PStotal', 'J0395_PStotal', 'J0410_PStotal', 'J0430_PStotal',
#        'g_PStotal', 'J0515_PStotal', 'r_PStotal', 'J0660_PStotal', 'i_PStotal',
#        'J0861_PStotal', 'z_PStotal', 'e_u_PStotal', 'e_J0378_PStotal',
#        'e_J0395_PStotal', 'e_J0410_PStotal', 'e_J0430_PStotal', 'e_g_PStotal',
#        'e_J0515_PStotal', 'e_r_PStotal', 'e_J0660_PStotal', 'e_i_PStotal',
#        'e_J0861_PStotal', 'e_z_PStotal'],
#       dtype='object')

# %%
csv
# Out:
#                                          Field          RA        DEC  \
# ID
# b'iDR3.SPLUS-n14s03.023094 '  b'SPLUS-n14s03 '  152.818127 -17.691007
# b'iDR3.HYDRA-0077.084865   '  b'HYDRA-0077   '  150.383353 -33.043261
# b'iDR3.SPLUS-s23s45.020422 '  b'SPLUS-s23s45 '  352.251832 -29.779436
# b'iDR3.SPLUS-n18s18.000089 '  b'SPLUS-n18s18 '  174.850744 -23.627453
# b'iDR3.HYDRA-0049.043611   '  b'HYDRA-0049   '  149.681164 -29.463707
# ...                                        ...         ...        ...
# b'iDR3.SPLUS-n03s18.004879 '  b'SPLUS-n03s18 '  174.344407  -3.312593
# b'iDR3.STRIPE82-0125.029072'  b'STRIPE82-0125'  327.127535  -0.797904
# b'iDR3.STRIPE82-0132.057659'  b'STRIPE82-0132'  331.015699   1.107458
# b'iDR3.SPLUS-s23s19.013644 '  b'SPLUS-s23s19 '   28.196811 -29.890678
# b'iDR3.STRIPE82-0061.047759'  b'STRIPE82-0061'   42.220210  -0.345029
#
#                                   FWHM  ISOarea  KRON_RADIUS     MU_MAX  \
# ID
# b'iDR3.SPLUS-n14s03.023094 '  2.162409      525     2.547039  10.630968
# b'iDR3.HYDRA-0077.084865   '  2.060758      271     2.745416  12.111699
# b'iDR3.SPLUS-s23s45.020422 '  2.044366      246     2.879416  11.472648
# b'iDR3.SPLUS-n18s18.000089 '  2.552651      252     2.627111  10.996559
# b'iDR3.HYDRA-0049.043611   '  3.168911      395     3.058134  11.737776
# ...                                ...      ...          ...        ...
# b'iDR3.SPLUS-n03s18.004879 '  5.641993       15     6.179567  17.176810
# b'iDR3.STRIPE82-0125.029072'  2.090127        7     1.820000  16.853830
# b'iDR3.STRIPE82-0132.057659'  3.068043       10     5.251886  17.315880
# b'iDR3.SPLUS-s23s19.013644 '  6.469779       10     5.489925  17.634684
# b'iDR3.STRIPE82-0061.047759'  2.540941       53     8.001971  16.101028
#
#                               nDet_PStotal  PhotoFlagDet  CLASS_STAR  ...  \
# ID                                                                    ...
# b'iDR3.SPLUS-n14s03.023094 '          12.0             0    0.985563  ...
# b'iDR3.HYDRA-0077.084865   '          12.0             0    0.974406  ...
# b'iDR3.SPLUS-s23s45.020422 '          12.0             0    0.994988  ...
# b'iDR3.SPLUS-n18s18.000089 '          12.0             0    0.972722  ...
# b'iDR3.HYDRA-0049.043611   '          12.0             0    0.871400  ...
# b'iDR3.STRIPE82-0061.047759'         0.230515     0.190616
#
# [2187 rows x 34 columns]

# %% [markdown]
# # Novo Data Frame

# %%
# Tratando o data frame
count = 0
c = 0
for column in csv.columns:
    count +=1
    print(f"{count} - {column}")
    # Pegando apenas os 12 filtros de magnitude
    if count >= 11 and count <= 22:
        df[c] = csv[column]
        df.rename(columns = {c:column}, inplace = True)
        c += 1
# Out:
# 1 - Field
# 2 - RA
# 3 - DEC
# 4 - FWHM
# 5 - ISOarea
# 6 - KRON_RADIUS
# 7 - MU_MAX
# 8 - nDet_PStotal
# 9 - PhotoFlagDet
# 10 - CLASS_STAR
# 11 - u_PStotal
# 12 - J0378_PStotal
# 13 - J0395_PStotal
# 14 - J0410_PStotal
# 15 - J0430_PStotal
# 16 - g_PStotal
# 17 - J0515_PStotal
# 18 - r_PStotal
# 19 - J0660_PStotal
# 20 - i_PStotal
# 21 - J0861_PStotal
# 22 - z_PStotal
# 23 - e_u_PStotal
# 24 - e_J0378_PStotal
# 25 - e_J0395_PStotal
# 26 - e_J0410_PStotal
# 27 - e_J0430_PStotal
# 28 - e_g_PStotal
# 29 - e_J0515_PStotal
# 30 - e_r_PStotal
# 31 - e_J0660_PStotal
# 32 - e_i_PStotal
# 33 - e_J0861_PStotal
# 34 - e_z_PStotal

# %%
# Novo Data Frame com apenas os 12 filtros
df
# Out:
#                               u_PStotal  J0378_PStotal  J0395_PStotal  \
# ID
# b'iDR3.SPLUS-n14s03.023094 '  16.675000      16.575087      16.565655
# b'iDR3.HYDRA-0077.084865   '  15.377505      15.103262      15.133448
# b'iDR3.SPLUS-s23s45.020422 '  15.014418      15.013782      14.862950
# b'iDR3.SPLUS-n18s18.000089 '  19.206873      18.916110      18.565432
# b'iDR3.HYDRA-0049.043611   '  16.499258      16.071520      15.847940
# ...                                 ...            ...            ...
# b'iDR3.SPLUS-n03s18.004879 '  21.547806      21.304468      22.342650
# b'iDR3.STRIPE82-0125.029072'  21.961760      21.633818      21.945740
# b'iDR3.STRIPE82-0132.057659'  21.442451      22.669330      20.962551
# b'iDR3.SPLUS-s23s19.013644 '  21.626970      22.156849      23.343393
# b'iDR3.STRIPE82-0061.047759'  20.893192      20.312292      20.402306
#
#                               J0410_PStotal  J0430_PStotal  g_PStotal  \
# ID
# b'iDR3.SPLUS-n14s03.023094 '      16.527618      16.304626  15.712595
# b'iDR3.HYDRA-0077.084865   '      15.320404      15.284002  15.461737
# b'iDR3.SPLUS-s23s45.020422 '      15.409410      15.349426  15.492199
# b'iDR3.SPLUS-n18s18.000089 '      17.605415      16.900711  16.123627
# b'iDR3.HYDRA-0049.043611   '      15.568316      15.472755  15.513618
# ...                                     ...            ...        ...
# b'iDR3.SPLUS-n03s18.004879 '      21.574844      21.349382  21.170525
# b'iDR3.STRIPE82-0125.029072'      22.737680      22.108326  21.432835
# b'iDR3.STRIPE82-0132.057659'      21.231575      21.084188  21.397928
# b'iDR3.SPLUS-s23s19.013644 '      22.490442      22.244430  21.534729
# b'iDR3.STRIPE82-0061.047759'      21.052319      20.850900  19.856806
#
#                               J0515_PStotal  r_PStotal  J0660_PStotal  \
# ID
# b'iDR3.SPLUS-n14s03.023094 '      15.602545  14.579465      14.041800
# b'iDR3.HYDRA-0077.084865   '      15.157310  15.294937      14.924424
# b'iDR3.SPLUS-s23s45.020422 '      15.614660  15.360847      15.001359
# b'iDR3.SPLUS-n18s18.000089 '      16.050580  15.496835      14.925963
# b'iDR3.HYDRA-0049.043611   '      15.656550  15.418391      14.922369
# ...                                     ...        ...            ...
# b'iDR3.SPLUS-n03s18.004879 '      21.496216  20.731617      19.896550
# b'iDR3.STRIPE82-0125.029072'      21.321358  20.853798      19.913960
# b'iDR3.STRIPE82-0132.057659'      21.439405  20.878489      19.952087
# b'iDR3.SPLUS-s23s19.013644 '      21.018692  20.812530      20.167912
# b'iDR3.STRIPE82-0061.047759'      18.584140  20.165321      18.327484
#
#                               i_PStotal  J0861_PStotal  z_PStotal
# ID
# b'iDR3.SPLUS-n14s03.023094 '  14.135739      13.788973  13.767706
# b'iDR3.HYDRA-0077.084865   '  15.239864      15.167364  15.103933
# b'iDR3.SPLUS-s23s45.020422 '  15.375683      15.355514  15.372553
# b'iDR3.SPLUS-n18s18.000089 '  14.985117      14.378416  14.279529
# b'iDR3.HYDRA-0049.043611   '  15.678785      14.766943  15.023354
# ...                                 ...            ...        ...
# b'iDR3.SPLUS-n03s18.004879 '  20.808970      20.118773  20.286373
# b'iDR3.STRIPE82-0125.029072'  20.692501      20.279907  20.650448
# b'iDR3.STRIPE82-0132.057659'  21.123137      20.181057  21.402450
# b'iDR3.SPLUS-s23s19.013644 '  21.030071      20.548590  21.131628
# b'iDR3.STRIPE82-0061.047759'  20.750933      20.675160  20.754830
#
# [2187 rows x 12 columns]

# %% [markdown]
# # Teste1 PCA

# %%
pca = PCA(4)

# %%
# Identificando quantos componentes serão necenssários
pca = PCA().fit(df)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# Verificando, 4 componentes é o necessário para essa base!

# %%
df_pca = pca.fit_transform(df)

# %%
print(f"Data Frame Shape: {df.shape}")
print(f"PCA Frame Shape: {df_pca.shape}")
# Out:
# Data Frame Shape: (2187, 12)
# PCA Frame Shape: (2187, 12)

# %%
df_pca
# Out:
# array([[-23.03067123,  -0.62700379,  -0.13531323, ...,   3.76462111,
#           0.2876494 ,   0.13134093],
#        [-25.89632795,  -0.68046044,  -0.2851687 , ...,   3.10730016,
#           0.24504243,   0.31153805],
#        [-26.1926057 ,  -0.62760666,  -0.08420179, ...,   3.08626409,
#           0.25570761,   0.35070262],
#        ...,
#        [-11.58604175,   0.79630266,   1.25831326, ...,  -1.4973185 ,
#           0.21632235,   0.11395863],
#        [ -9.74301436,  -0.99801801,   0.45862625, ...,  -1.33896365,
#          -0.03353901,   0.1218775 ],
#        [-13.69414255,   0.2281751 ,  -0.18413977, ...,  -0.20998282,
#           1.21041434,   0.31787705]])

# %%
pca.explained_variance_
# Out:
# array([9.95252089e+02, 3.53976097e+02, 3.25485908e+02, 2.58687782e+02,
#        2.03759218e+02, 4.26006774e+01, 1.65312507e+01, 9.68561036e+00,
#        4.52778007e+00, 1.45093542e+00, 1.43218017e-01, 4.98979734e-02])

# %%
plt.scatter(df_pca[:, 0], df_pca[:, 1], alpha=0.2)
plt.xlabel('Component 0')
plt.ylabel('Component 1');
plt.axis('equal');

# %%
plt.scatter(df_pca[:, 2], df_pca[:, 3], alpha=0.2)
plt.xlabel('Component 2')
plt.ylabel('Component 3');
plt.axis('equal');

# %%
plt.scatter(df_pca[:, 0], df_pca[:, 3], alpha=0.2)
plt.xlabel('Component 0')
plt.ylabel('Component 3');
plt.axis('equal');

# %%
plt.scatter(df_pca[:, 0], df_pca[:, 2], alpha=0.2)
plt.xlabel('Component 0')
plt.ylabel('Component 2');
plt.axis('equal');

# %% [markdown]
# # Teste2 PCA
